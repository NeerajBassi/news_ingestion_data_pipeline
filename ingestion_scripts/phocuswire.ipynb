# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.12.2)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.13.4 soupsieve-2.7
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://skift.com/news/"
page = 1
while True:
    # Compose the page URL (first page is just the base, subsequent pages are /page/2/, etc.)
    if page == 1:
        url = base_url
    else:
        url = f"{base_url}page/{page}/"

    response = requests.get(url)
    if response.status_code != 200:
        break  # No more pages

    soup = BeautifulSoup(response.text, "html.parser")
    articles = soup.select("article")
    if not articles:
        break  # No articles means end of pagination

    for article in articles:
        # extract info as before...
        pass

    # Proceed to next page
    # page += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#      10 else:
#      11     url = f"{base_url}page/{page}/"
# ---> 13 response = requests.get(url)
#      14 if response.status_code != 200:
#      15     break  # No more pages
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
base_url = "https://skift.com/news/"
page = 1

url = f"{base_url}page/{page}/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

# %%
print(len(articles))
# Out:
# 12

# %%
articles = soup.select("article")
print(articles)
# Out:
# [<article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="What if Airbnb Builds the Killer AI Travel Search App?" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://skift.com/2025/07/27/what-if-airbnb-builds-the-killer-ai-travel-search-app/">
# <img alt="Airbnb's app" class="" decoding="async" height="683" loading="lazy" src="https://skift.com/wp-content/uploads/2025/07/Upgrades-for-Guests-2024-Winter-Release-e1753459527633.jpg?w=1024" width="1024"> </img></a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033"><a class="" href="https://skift.com/travel-technology/">Travel Technology</a></div>
# <h3 class="c-tease__title">
# <a href="https://skift.com/2025/07/27/what-if-airbnb-builds-the-killer-ai-travel-search-app/">
#                     What if Airbnb Builds the Killer AI Travel Search App?                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 Airbnb is hiring an engineer for an AI-powered natural language search product. If the tech delivers, it could create new creative pressure in shaping how people choose where to go and stay.
#             </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/sarah-kopit/">Sarah Kopit</a> | <time class="o-pretty-time-relative" datetime="2025-07-27T10:39:11-04:00">3 hours ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Etihad Airways CEO Unpacks Big Bet on Small Jets" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://skift.com/2025/07/26/etihad-airways-ceo-unpacks-big-bet-on-small-jets/">
# <img alt="The first class suite onboard Etihad's new A321LR." class="" decoding="async" height="710" loading="lazy" sizes="auto, (max-width: 1024px) 100vw, 1024px" src="https://skift.com/wp-content/uploads/2025/07/A321LR-First-Cabin-e1753529516877.jpg?w=1024" srcset="https://skift.com/wp-content/uploads/2025/07/A321LR-First-Cabin-e1753529516877.jpg 1370w, https://skift.com/wp-content/uploads/2025/07/A321LR-First-Cabin-e1753529516877.jpg?resize=300,208 300w, https://skift.com/wp-content/uploads/2025/07/A321LR-First-Cabin-e1753529516877.jpg?resize=768,533 768w, https://skift.com/wp-content/uploads/2025/07/A321LR-First-Cabin-e1753529516877.jpg?resize=1024,710 1024w, https://skift.com/wp-content/uploads/2025/07/A321LR-First-Cabin-e1753529516877.jpg?resize=87,60 87w, https://skift.com/wp-content/uploads/2025/07/A321LR-First-Cabin-e1753529516877.jpg?resize=173,120 173w" width="1024"/> </a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033"><a class="" href="https://skift.com/airlines/">Airlines</a></div>
# <h3 class="c-tease__title">
# <a href="https://skift.com/2025/07/26/etihad-airways-ceo-unpacks-big-bet-on-small-jets/">
#                     Etihad Airways CEO Unpacks Big Bet on Small Jets                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 Etihad is hoping to outmaneuver its Gulf rivals with 30 small but premium aircraft. Will passengers buy the promise of private jet-like luxury?            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/gordon-smith/">Gordon Smith</a> | <time class="o-pretty-time-relative" datetime="2025-07-26T14:10:05-04:00">24 hours ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="5 Ways to Design a Transformational Event: Advice from Disney" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://meetings.skift.com/2025/07/25/5-ways-to-design-a-transformational-event-advice-from-disney/">
# <img decoding="async" loading="lazy" src="https://meetings.skift.com/wp-content/uploads/2025/07/DisneyCreativeStudio_Casting-Office-e1753484901870.jpg"/> </a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033">Skift Meetings <span class="material-icons-outlined" style="font-size:inherit">launch</span></div>
# <h3 class="c-tease__title">
# <a href="https://meetings.skift.com/2025/07/25/5-ways-to-design-a-transformational-event-advice-from-disney/" target="_blank">
#                     5 Ways to Design a Transformational Event: Advice from Disney                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 As attendees crave deeper meaning and stronger emotional connections, Disney Meetings &amp; Events is leaning into its storytelling roots.  At the heart of its strategy is the Disney Creative Studio, a collaborative hub where storytelling drives experiences that truly transform.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/andrea-doyle/">Andrea Doyle</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T19:17:38-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Human Connection Will Save Your Event (Not More Content)" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://meetings.skift.com/2025/07/25/human-connection-will-save-your-event-not-more-content/">
# <img decoding="async" loading="lazy" src="https://meetings.skift.com/wp-content/uploads/2025/07/7f64fd92-2702-42b4-af3b-919ffcd4b7ec.png"/> </a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033">Skift Meetings <span class="material-icons-outlined" style="font-size:inherit">launch</span></div>
# <h3 class="c-tease__title">
# <a href="https://meetings.skift.com/2025/07/25/human-connection-will-save-your-event-not-more-content/" target="_blank">
#                     Human Connection Will Save Your Event (Not More Content)                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 As costs rise and loyalty declines, connection can’t be an afterthought. Planners who fail to prioritize it risk losing attendees, and with them, their event’s future.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/andrea-doyle/">Andrea Doyle</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T14:10:39-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="What Your International Attendees Need to Know to Enter the U.S." class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://meetings.skift.com/2025/07/25/what-your-international-attendees-need-to-know-to-enter-the-u-s/">
# <img decoding="async" loading="lazy" src="https://meetings.skift.com/wp-content/uploads/2025/07/patty-zavala-TKwGZ9a6YHU-unsplash.jpg"/> </a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033">Skift Meetings <span class="material-icons-outlined" style="font-size:inherit">launch</span></div>
# <h3 class="c-tease__title">
# <a href="https://meetings.skift.com/2025/07/25/what-your-international-attendees-need-to-know-to-enter-the-u-s/" target="_blank">
#                     What Your International Attendees Need to Know to Enter the U.S.                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 U.S. entry requirements vary by country and can be confusing. We break it down for you.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/barbara-scofidio/">Barbara Scofidio</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T13:25:41-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Former Six Senses CEO Has a New Venture: Here’s How He’s Advising Other Hotel Groups" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://skift.com/2025/07/25/former-six-senses-ceo-has-a-new-venture-heres-how-hes-advising-other-hotel-groups/">
# <img alt="a smiling luxury hotel executive, Neil Jacobs" class="" decoding="async" height="683" loading="lazy" sizes="auto, (max-width: 1024px) 100vw, 1024px" src="https://skift.com/wp-content/uploads/2025/06/Six-Senses-CEO-Neil-Jacobs-source-ihg.jpg?w=1024" srcset="https://skift.com/wp-content/uploads/2025/06/Six-Senses-CEO-Neil-Jacobs-source-ihg.jpg 1203w, https://skift.com/wp-content/uploads/2025/06/Six-Senses-CEO-Neil-Jacobs-source-ihg.jpg?resize=300,200 300w, https://skift.com/wp-content/uploads/2025/06/Six-Senses-CEO-Neil-Jacobs-source-ihg.jpg?resize=768,512 768w, https://skift.com/wp-content/uploads/2025/06/Six-Senses-CEO-Neil-Jacobs-source-ihg.jpg?resize=1024,683 1024w, https://skift.com/wp-content/uploads/2025/06/Six-Senses-CEO-Neil-Jacobs-source-ihg.jpg?resize=90,60 90w, https://skift.com/wp-content/uploads/2025/06/Six-Senses-CEO-Neil-Jacobs-source-ihg.jpg?resize=180,120 180w" width="1024"> </img></a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033"><a class="" href="https://skift.com/hotels/">Hotels</a></div>
# <h3 class="c-tease__title">
# <a href="https://skift.com/2025/07/25/former-six-senses-ceo-has-a-new-venture-heres-how-hes-advising-other-hotel-groups/">
#                     Former Six Senses CEO Has a New Venture: Here’s How He’s Advising Other Hotel Groups                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 Neil Jacobs stepped away from operations but not from hospitality. With Wild Origins, he’s helping brands scale with purpose and avoid the pitfalls he’s seen before.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/luke-martin/">Luke Martin</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T12:36:08-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Extreme Heat in Greece Triggers Safety Warnings for Tourists, Forces Partial Shut Down of Acropolis " class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://skift.com/2025/07/25/extreme-heat-in-greece-triggers-safety-warnings-for-tourists-forces-partial-shut-down-of-acropolis/">
# <img alt="" class="" decoding="async" height="645" loading="lazy" sizes="auto, (max-width: 1024px) 100vw, 1024px" src="https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?w=1024" srcset="https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png 2210w, https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?resize=300,189 300w, https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?resize=768,484 768w, https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?resize=1024,645 1024w, https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?resize=1536,967 1536w, https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?resize=2048,1290 2048w, https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?resize=95,60 95w, https://skift.com/wp-content/uploads/2025/07/Screenshot-2025-07-25-at-16.28.25.png?resize=191,120 191w" width="1024"> </img></a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033"><a class="" href="https://skift.com/tourism/">Tourism</a></div>
# <h3 class="c-tease__title">
# <a href="https://skift.com/2025/07/25/extreme-heat-in-greece-triggers-safety-warnings-for-tourists-forces-partial-shut-down-of-acropolis/">
#                     Extreme Heat in Greece Triggers Safety Warnings for Tourists, Forces Partial Shut Down of Acropolis                 </a>
# </h3>
# <div class="c-tease__excerpt">
#                 The increasing frequency of heat events is raising fresh questions about climate resilience in Mediterranean tourism markets, especially as the peak season now coincides with dangerous weather extremes.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/darin-graham/">Darin Graham</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T11:33:14-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Grand Canyon Fires Are Still Burning, Adventure Companies Shift Trips" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://skift.com/2025/07/25/the-grand-canyon-fires-are-still-burning-adventure-companies-shift-trips/">
# <img alt="" class="" decoding="async" height="768" loading="lazy" sizes="auto, (max-width: 1024px) 100vw, 1024px" src="https://skift.com/wp-content/uploads/2025/07/NPS.NICK-MANN-FIREFIGHER-IN-FRONT-OF-DRAGON-BRAVO-FIRE-e1753453254955.jpg?w=1024" srcset="https://skift.com/wp-content/uploads/2025/07/NPS.NICK-MANN-FIREFIGHER-IN-FRONT-OF-DRAGON-BRAVO-FIRE-e1753453254955.jpg 1200w, https://skift.com/wp-content/uploads/2025/07/NPS.NICK-MANN-FIREFIGHER-IN-FRONT-OF-DRAGON-BRAVO-FIRE-e1753453254955.jpg?resize=300,225 300w, https://skift.com/wp-content/uploads/2025/07/NPS.NICK-MANN-FIREFIGHER-IN-FRONT-OF-DRAGON-BRAVO-FIRE-e1753453254955.jpg?resize=768,576 768w, https://skift.com/wp-content/uploads/2025/07/NPS.NICK-MANN-FIREFIGHER-IN-FRONT-OF-DRAGON-BRAVO-FIRE-e1753453254955.jpg?resize=1024,768 1024w, https://skift.com/wp-content/uploads/2025/07/NPS.NICK-MANN-FIREFIGHER-IN-FRONT-OF-DRAGON-BRAVO-FIRE-e1753453254955.jpg?resize=80,60 80w, https://skift.com/wp-content/uploads/2025/07/NPS.NICK-MANN-FIREFIGHER-IN-FRONT-OF-DRAGON-BRAVO-FIRE-e1753453254955.jpg?resize=160,120 160w" width="1024"> </img></a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033"><a class="" href="https://skift.com/tourism/">Tourism</a></div>
# <h3 class="c-tease__title">
# <a href="https://skift.com/2025/07/25/the-grand-canyon-fires-are-still-burning-adventure-companies-shift-trips/">
#                     Grand Canyon Fires Are Still Burning, Adventure Companies Shift Trips                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 The Grand Canyon fires are some the worst to hit the region. A sobering reminder that extreme weather can affect iconic natural landmarks.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/darin-graham/">Darin Graham</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T10:21:08-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Building Connections at Skift Global Forum 2025: Before, During, and After the Event" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://live.skift.com/blog/skift-global-forum-networking-guide/">
# <img decoding="async" loading="lazy" src="https://live.skift.com/wp-content/uploads/2025/07/attendees-networking-at-Skift-Global-Forum.jpg"/> </a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033">Skift Live</div>
# <h3 class="c-tease__title">
# <a href="https://live.skift.com/blog/skift-global-forum-networking-guide/" target="_blank">
#                     Building Connections at Skift Global Forum 2025: Before, During, and After the Event                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 Known for its energy, warmth, and a room full of decision-makers, Skift Global Forum has helped thousands of leaders, entrepreneurs, and investors build relationships that shape what’s next in travel.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/kanchi-jain/">Kanchi Jain</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T10:00:01-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Every One of Radisson’s Hotel Brands, Explained" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://skift.com/2025/07/25/every-one-of-radissons-hotel-brands-explained/">
# <img alt="Radisson Hotel Danang" class="" decoding="async" height="684" loading="lazy" sizes="auto, (max-width: 1024px) 100vw, 1024px" src="https://skift.com/wp-content/uploads/2022/09/Radisson-Hotel-Danang-e1665392536601.jpg?w=1024" srcset="https://skift.com/wp-content/uploads/2022/09/Radisson-Hotel-Danang-e1665392536601.jpg 1201w, https://skift.com/wp-content/uploads/2022/09/Radisson-Hotel-Danang-e1665392536601.jpg?resize=300,200 300w, https://skift.com/wp-content/uploads/2022/09/Radisson-Hotel-Danang-e1665392536601.jpg?resize=768,513 768w, https://skift.com/wp-content/uploads/2022/09/Radisson-Hotel-Danang-e1665392536601.jpg?resize=1024,684 1024w, https://skift.com/wp-content/uploads/2022/09/Radisson-Hotel-Danang-e1665392536601.jpg?resize=90,60 90w, https://skift.com/wp-content/uploads/2022/09/Radisson-Hotel-Danang-e1665392536601.jpg?resize=180,120 180w" width="1024"> </img></a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033"><a class="" href="https://skift.com/hotels/">Hotels</a></div>
# <h3 class="c-tease__title">
# <a href="https://skift.com/2025/07/25/every-one-of-radissons-hotel-brands-explained/">
#                     Every One of Radisson’s Hotel Brands, Explained                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 Radisson is quietly reinventing itself through regional focus and flexible branding, trading name recognition for market adaptability.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/luke-martin/">Luke Martin</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T09:27:21-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Airfare AI Debates, Hotel EV Demand and Southwest’s Baggage Bonanzas" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://skift.com/2025/07/25/airfare-ai-debates-hotel-ev-demand-and-southwests-baggage-bonanzas/">
# <img alt="people picking up suitcase on luggage conveyor belt in the airport" class="" decoding="async" height="683" loading="lazy" sizes="auto, (max-width: 1024px) 100vw, 1024px" src="https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg?w=1024" srcset="https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg 2048w, https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg?resize=300,200 300w, https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg?resize=768,512 768w, https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg?resize=1024,683 1024w, https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg?resize=1536,1024 1536w, https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg?resize=90,60 90w, https://skift.com/wp-content/uploads/2024/02/IMG_3824-scaled.jpeg?resize=180,120 180w" width="1024"/> </a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033"><a class="" href="https://skift.com/podcasts/">Podcasts</a></div>
# <h3 class="c-tease__title">
# <a href="https://skift.com/2025/07/25/airfare-ai-debates-hotel-ev-demand-and-southwests-baggage-bonanzas/">
#                     Airfare AI Debates, Hotel EV Demand and Southwest’s Baggage Bonanzas                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 In the headphones today: American Air makes an AI pricing promise, Hilton says EV charging is an edge, and Southwest’s billion dollar bonus.             </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/rashaad-jorden/">Rashaad Jorden</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T04:19:23-04:00">2 days ago</time></div>
# </div>
# </article>, <article class="c-tease is-image-left is-size-default">
# <div class="c-tease__image">
# <a aria-label="Skift Meetings Forum: What to Expect" class="o-aspect-ratio o-aspect-ratio--3by2 has-placeholder" href="https://live.skift.com/skift-meetings-forum-what-to-expect/">
# <img decoding="async" loading="lazy" src="https://live.skift.com/wp-content/uploads/2025/07/what-to-expect-at-Skift-Meetings-Forum.jpg"/> </a>
# </div>
# <div class="c-tease__content is-layout-flow">
# <div class="c-tease__eyebrow has-tertiary-font-family" style="color: #f34033">Skift Live</div>
# <h3 class="c-tease__title">
# <a href="https://live.skift.com/skift-meetings-forum-what-to-expect/" target="_blank">
#                     Skift Meetings Forum: What to Expect                </a>
# </h3>
# <div class="c-tease__excerpt">
#                 Skift Meetings Forum returns September 15, 2025, to City Winery NYC, bringing together over 250 senior event professionals for bold ideas, real-world insights, and direct access to industry leaders.            </div>
# <div class="c-tease__byline has-tertiary-font-family"><a class="underline" href="https://skift.com/author/kanchi-jain/">Kanchi Jain</a> | <time class="o-pretty-time-relative" datetime="2025-07-25T00:45:26-04:00">3 days ago</time></div>
# </div>
# </article>]

# %%
articles_data = []

for article in soup.select("article"):
    label_tag = article.select_one("div.c-tease__eyebrow")
    label = label_tag.text.strip() if label_tag else None

    link_tag = article.select_one("h3.c-tease__title a")
    news_link = link_tag['href'] if link_tag else None

    author_tag = article.select_one("div.c-tease__byline a.underline")
    author = author_tag.text.strip() if author_tag else None

    time_tag = article.select_one("div.c-tease__byline time")
    news_time = time_tag.get("datetime") if time_tag else None

    articles_data.append({
        "label": label,
        "news_link": news_link,
        "author": author,
        "news_time": news_time,
        "Source": "Skift"
    })

# Preview extracted data
for item in articles_data:
    print(item)
# Out:
# {'label': 'Travel Technology', 'news_link': 'https://skift.com/2025/07/27/what-if-airbnb-builds-the-killer-ai-travel-search-app/', 'author': 'Sarah Kopit', 'news_time': '2025-07-27T10:39:11-04:00', 'Source': 'Skift'}
# {'label': 'Airlines', 'news_link': 'https://skift.com/2025/07/26/etihad-airways-ceo-unpacks-big-bet-on-small-jets/', 'author': 'Gordon Smith', 'news_time': '2025-07-26T14:10:05-04:00', 'Source': 'Skift'}
# {'label': 'Skift Meetings launch', 'news_link': 'https://meetings.skift.com/2025/07/25/5-ways-to-design-a-transformational-event-advice-from-disney/', 'author': 'Andrea Doyle', 'news_time': '2025-07-25T19:17:38-04:00', 'Source': 'Skift'}
# {'label': 'Skift Meetings launch', 'news_link': 'https://meetings.skift.com/2025/07/25/human-connection-will-save-your-event-not-more-content/', 'author': 'Andrea Doyle', 'news_time': '2025-07-25T14:10:39-04:00', 'Source': 'Skift'}
# {'label': 'Skift Meetings launch', 'news_link': 'https://meetings.skift.com/2025/07/25/what-your-international-attendees-need-to-know-to-enter-the-u-s/', 'author': 'Barbara Scofidio', 'news_time': '2025-07-25T13:25:41-04:00', 'Source': 'Skift'}
# {'label': 'Hotels', 'news_link': 'https://skift.com/2025/07/25/former-six-senses-ceo-has-a-new-venture-heres-how-hes-advising-other-hotel-groups/', 'author': 'Luke Martin', 'news_time': '2025-07-25T12:36:08-04:00', 'Source': 'Skift'}
# {'label': 'Tourism', 'news_link': 'https://skift.com/2025/07/25/extreme-heat-in-greece-triggers-safety-warnings-for-tourists-forces-partial-shut-down-of-acropolis/', 'author': 'Darin Graham', 'news_time': '2025-07-25T11:33:14-04:00', 'Source': 'Skift'}
# {'label': 'Tourism', 'news_link': 'https://skift.com/2025/07/25/the-grand-canyon-fires-are-still-burning-adventure-companies-shift-trips/', 'author': 'Darin Graham', 'news_time': '2025-07-25T10:21:08-04:00', 'Source': 'Skift'}
# {'label': 'Skift Live', 'news_link': 'https://live.skift.com/blog/skift-global-forum-networking-guide/', 'author': 'Kanchi Jain', 'news_time': '2025-07-25T10:00:01-04:00', 'Source': 'Skift'}
# {'label': 'Hotels', 'news_link': 'https://skift.com/2025/07/25/every-one-of-radissons-hotel-brands-explained/', 'author': 'Luke Martin', 'news_time': '2025-07-25T09:27:21-04:00', 'Source': 'Skift'}
# {'label': 'Podcasts', 'news_link': 'https://skift.com/2025/07/25/airfare-ai-debates-hotel-ev-demand-and-southwests-baggage-bonanzas/', 'author': 'Rashaad Jorden', 'news_time': '2025-07-25T04:19:23-04:00', 'Source': 'Skift'}
# {'label': 'Skift Live', 'news_link': 'https://live.skift.com/skift-meetings-forum-what-to-expect/', 'author': 'Kanchi Jain', 'news_time': '2025-07-25T00:45:26-04:00', 'Source': 'Skift'}

# %%
import sqlite3
import hashlib
import os

DB_DIR = r"C:/Users/HP/Documents/repos/news_ingestion_data_pipeline/data"
DB_FILE = "articles.db"
DB_PATH = os.path.join(DB_DIR, DB_FILE)

def init_db():
    """Creates the articles table if it doesn't exist."""
    os.makedirs(DB_DIR, exist_ok=True)
    with sqlite3.connect(DB_PATH) as conn:
        conn.execute("""
            CREATE TABLE IF NOT EXISTS articles (
                article_id TEXT PRIMARY KEY,
                label TEXT,
                news_link TEXT,
                author TEXT,
                news_time TEXT,
                source TEXT
            )
        """)

def generate_article_id(url):
    """Generate a unique article ID by hashing the article URL."""
    return hashlib.md5(url.encode('utf-8')).hexdigest()

def insert_articles(articles):
    """
    Insert list of article dicts into the SQLite table.
    Each article dict should have keys:
    label, news_link, author, news_time, source
    """
    with sqlite3.connect(DB_PATH) as conn:
        for article in articles:
            article_id = generate_article_id(article['news_link'])
            try:
                conn.execute("""
                    INSERT OR IGNORE INTO articles 
                    (article_id, label, news_link, author, news_time, Source)
                    VALUES (?, ?, ?, ?, ?, ?)
                """, (
                    article_id,
                    article.get('label'),
                    article.get('news_link'),
                    article.get('author'),
                    article.get('news_time'),
                    article.get('Source')
                ))
            except Exception as e:
                print(f"Error inserting article {article['news_link']}: {e}")

if __name__ == "__main__":
    # Example extracted articles data
    # articles_data = [
    #     {
    #         "label": "Airlines",
    #         "news_link": "https://skift.com/2025/07/26/etihad-airways-ceo-unpacks-big-bet-on-small-jets/",
    #         "author": "Gordon Smith",
    #         "news_time": "2025-07-26T14:10:05-04:00",
    #         "source": "Skift"
    #     },
    #     # more articles ...
    # ]

    init_db()
    insert_articles(articles_data)
    print("Articles saved to SQLite database successfully!")
# Out:
# Articles saved to SQLite database successfully!

# %%
import sqlite3

DB_FILE = "articles.db"

def query_all_articles():
    # Connect to the SQLite database
    with sqlite3.connect(DB_PATH) as conn:
        cursor = conn.cursor()

        # Execute a query to select all articles
        cursor.execute("SELECT article_id, label, news_link, author, news_time, source FROM articles")

        # Fetch all rows returned by the query
        rows = cursor.fetchall()

        print(len(rows))
        # Process and display results
        for row in rows:
            article_id, label, news_link, author, news_time, source = row
            print(f"ID: {article_id}")
            print(f"Label: {label}")
            print(f"Link: {news_link}")
            print(f"Author: {author}")
            print(f"Published At: {news_time}")
            print(f"Source: {source}")
            print("-" * 40)


if __name__ == "__main__":
    query_all_articles()
# Out:
# 12
# ID: 680bdfc38e03d4dc46341415be1df193
# Label: Airlines
# Link: https://skift.com/2025/07/26/etihad-airways-ceo-unpacks-big-bet-on-small-jets/
# Author: Gordon Smith
# Published At: 2025-07-26T14:10:05-04:00
# Source: Skift
# ----------------------------------------
# ID: 112fa347e45d5fff1604a565ae5a01f2
# Label: Travel Technology
# Link: https://skift.com/2025/07/27/what-if-airbnb-builds-the-killer-ai-travel-search-app/
# Author: Sarah Kopit
# Published At: 2025-07-27T10:39:11-04:00
# Source: None
# ----------------------------------------
# ID: 38dce7c6cbc627ea4ad5e8ab0b66a866
# Label: None
# Link: https://meetings.skift.com/2025/07/25/5-ways-to-design-a-transformational-event-advice-from-disney/
# Author: Andrea Doyle
# Published At: 2025-07-25T19:17:38-04:00
# Source: None
# ----------------------------------------
# ID: 5993c1da434e0b2817b576a3201714e7
# Label: None
# Link: https://meetings.skift.com/2025/07/25/human-connection-will-save-your-event-not-more-content/
# Author: Andrea Doyle
# Published At: 2025-07-25T14:10:39-04:00
# Source: None
# ----------------------------------------
# ID: a4ca84232f43bb348626fcba3362db05
# Label: None
# Link: https://meetings.skift.com/2025/07/25/what-your-international-attendees-need-to-know-to-enter-the-u-s/
# Author: Barbara Scofidio
# Published At: 2025-07-25T13:25:41-04:00
# Source: None
# ----------------------------------------
# ID: 02284971a59b0c6d2b72750278d34e1d
# Label: Hotels
# Link: https://skift.com/2025/07/25/former-six-senses-ceo-has-a-new-venture-heres-how-hes-advising-other-hotel-groups/
# Author: Luke Martin
# Published At: 2025-07-25T12:36:08-04:00
# Source: None
# ----------------------------------------
# ID: d888e25524ac8d8d5377d6566bd41ed1
# Label: Tourism
# Link: https://skift.com/2025/07/25/extreme-heat-in-greece-triggers-safety-warnings-for-tourists-forces-partial-shut-down-of-acropolis/
# Author: Darin Graham
# Published At: 2025-07-25T11:33:14-04:00
# Source: None
# ----------------------------------------
# ID: db65bc4875cfa51e804895231f6b09ef
# Label: Tourism
# Link: https://skift.com/2025/07/25/the-grand-canyon-fires-are-still-burning-adventure-companies-shift-trips/
# Author: Darin Graham
# Published At: 2025-07-25T10:21:08-04:00
# Source: None
# ----------------------------------------
# ID: 5fad9c48e5c434eba91ed460cfb92ff3
# Label: None
# Link: https://live.skift.com/blog/skift-global-forum-networking-guide/
# Author: Kanchi Jain
# Published At: 2025-07-25T10:00:01-04:00
# Source: None
# ----------------------------------------
# ID: 94275d237a0d68e6f2f8a04341ccd7df
# Label: Hotels
# Link: https://skift.com/2025/07/25/every-one-of-radissons-hotel-brands-explained/
# Author: Luke Martin
# Published At: 2025-07-25T09:27:21-04:00
# Source: None
# ----------------------------------------
# ID: 37b35ee9d9b025602b89c6f95e211c3a
# Label: Podcasts
# Link: https://skift.com/2025/07/25/airfare-ai-debates-hotel-ev-demand-and-southwests-baggage-bonanzas/
# Author: Rashaad Jorden
# Published At: 2025-07-25T04:19:23-04:00
# Source: None
# ----------------------------------------
# ID: d103ba626a226ee486b908c3e2846018
# Label: None
# Link: https://live.skift.com/skift-meetings-forum-what-to-expect/
# Author: Kanchi Jain
# Published At: 2025-07-25T00:45:26-04:00
# Source: None
# ----------------------------------------
